# %% [markdown]
# ### Ineuron Internship
# - Nishant Banjade

# %% [markdown]
# #### Insurance premium prediction

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### EDA

# %%
#load the dataset
df = pd.read_csv('data_given/insurance.csv',sep=',',encoding='utf-8')

# %%
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %% [markdown]
# #### Check the null values

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %% [markdown]
# #### Conclusion: There is no null value in the dataset
# - For confirmation, let us draw heatmap

# %%
sns.heatmap(df.isna())
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### See the number of male and female

# %%
sns.countplot(df['sex'])
# Out:
# /home/nix-code/virtualenv/venv/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
df['sex'].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %% [markdown]
# #### Conclusion
# - There are 14 men more than the female

# %%
df.region.unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
plt.figure(figsize=(15,7))
sns.countplot(df['region'])
# Out:
# /home/nix-code/virtualenv/venv/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='region', ylabel='count'>

# %% [markdown]
# #### People are most likely from southeast region

# %%
plt.figure(figsize=(15,7))
plt.title("Age group histogram")
plt.hist(df['age'],bins=17)
plt.show()

# %%
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
df['children'].describe()
# Out:
# count    1338.000000
# mean        1.094918
# std         1.205493
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         2.000000
# max         5.000000
# Name: children, dtype: float64

# %%
plt.bar(df['sex'],df['bmi'])
# Out:
# <BarContainer object of 1338 artists>

# %% [markdown]
# ### Seems like male has higher BMI in comparision to female

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['sex'] = le.fit_transform(df['sex'])
df['smoker'] = le.fit_transform(df['smoker'])
df['region'] = le.fit_transform(df['region'])

# %%
df.head()
# Out:
#    age  sex   bmi  children  smoker  region  expenses
# 0    1    0  27.9         0       1       3  16884.92
# 1    0    1  33.8         1       0       2   1725.55
# 2   10    1  33.0         3       0       2   4449.46
# 3   15    1  22.7         0       0       1  21984.47
# 4   14    1  28.9         0       0       1   3866.86

# %%
plt.pie(df['sex'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f84f0506880>,
#   <matplotlib.patches.Wedge at 0x7f84f0506c40>,
#   <matplotlib.patches.Wedge at 0x7f84f0514100>,
#   <matplotlib.patches.Wedge at 0x7f84f05144f0>,
#   <matplotlib.patches.Wedge at 0x7f84f05149d0>,
#   <matplotlib.patches.Wedge at 0x7f84f0514eb0>,
#   <matplotlib.patches.Wedge at 0x7f84eec9a3d0>,
#   <matplotlib.patches.Wedge at 0x7f84eec9a8b0>,
#   <matplotlib.patches.Wedge at 0x7f84eec9ad90>,
#   <matplotlib.patches.Wedge at 0x7f84eeca72b0>,
#   <matplotlib.patches.Wedge at 0x7f84f0506850>,
#   <matplotlib.patches.Wedge at 0x7f84eeca7c40>,
#   <matplotlib.patches.Wedge at 0x7f84eecb3160>,
#   <matplotlib.patches.Wedge at 0x7f84eecb3640>,
#   <matplotlib.patches.Wedge at 0x7f84eecb3b20>,
#   <matplotlib.patches.Wedge at 0x7f84eeccd040>,
#   <matplotlib.patches.Wedge at 0x7f84eeccd520>,
#   <matplotlib.patches.Wedge at 0x7f84eeccda00>,
#   <matplotlib.patches.Wedge at 0x7f84eeccdee0>,
#   <matplotlib.patches.Wedge at 0x7f84eecd3400>,
#   <matplotlib.patches.Wedge at 0x7f84eecd38e0>,
#   <matplotlib.patches.Wedge at 0x7f84eecd3dc0>,
#   <matplotlib.patches.Wedge at 0x7f84eec5d2e0>,
#   <matplotlib.patches.Wedge at 0x7f84eec5d7c0>,
#   <matplotlib.patches.Wedge at 0x7f84eec5dca0>,
#   <matplotlib.patches.Wedge at 0x7f84eec691c0>,
#   <matplotlib.patches.Wedge at 0x7f84eec696a0>,
#   <matplotlib.patches.Wedge at 0x7f84eec69b80>,
#   <matplotlib.patches.Wedge at 0x7f84eec780a0>,
#   <matplotlib.patches.Wedge at 0x7f84eec78580>,
#   <matplotlib.patches.Wedge at 0x7f84eec78a60>,
#   <matplotlib.patches.Wedge at 0x7f84eec78f40>,
#   <matplotlib.patches.Wedge at 0x7f84eec90460>,
#   <matplotlib.patches.Wedge at 0x7f84eec90940>,
#   <matplotlib.patches.Wedge at 0x7f84eec90e20>,
#   <matplotlib.patches.Wedge at 0x7f84eebbb340>,
#   <matplotlib.patches.Wedge at 0x7f84eebbb820>,
#   <matplotlib.patches.Wedge at 0x7f84eebbbd00>,
#   <matplotlib.patches.Wedge at 0x7f84eeba0220>,
#   <matplotlib.patches.Wedge at 0x7f84eeba0700>,
#   <matplotlib.patches.Wedge at 0x7f84eeba0be0>,
#   <matplotlib.patches.Wedge at 0x7f84eebab100>,
#   <matplotlib.patches.Wedge at 0x7f84eebab5e0>,
#   <matplotlib.patches.Wedge at 0x7f84eebabac0>,
#   <matplotlib.patches.Wedge at 0x7f84eebabfa0>,
#   <matplotlib.patches.Wedge at 0x7f84eebc64c0>,
#   <matplotlib.patches.Wedge at 0x7f84eebc69a0>,
#   <matplotlib.patches.Wedge at 0x7f84eebc6e80>,
#   <matplotlib.patches.Wedge at 0x7f84eebcb3a0>,
#   <matplotlib.patches.Wedge at 0x7f84eebcb880>,
#   <matplotlib.patches.Wedge at 0x7f84eebcbd60>,
#   <matplotlib.patches.Wedge at 0x7f84eebd7280>,
#   <matplotlib.patches.Wedge at 0x7f84eebd7760>,
#   <matplotlib.patches.Wedge at 0x7f84eebd7c40>,
#   <matplotlib.patches.Wedge at 0x7f84eebe4160>,
#   <matplotlib.patches.Wedge at 0x7f84eebe4640>,
#   <matplotlib.patches.Wedge at 0x7f84eebe4b20>,
#   <matplotlib.patches.Wedge at 0x7f84eebf0040>,
#   <matplotlib.patches.Wedge at 0x7f84eebf0520>,
#   <matplotlib.patches.Wedge at 0x7f84eebf0a00>,
#   <matplotlib.patches.Wedge at 0x7f84eebf0ee0>,
#   <matplotlib.patches.Wedge at 0x7f84eebfd400>,
#   <matplotlib.patches.Wedge at 0x7f84eebfd8e0>,
#   <matplotlib.patches.Wedge at 0x7f84eebfddc0>,
#   <matplotlib.patches.Wedge at 0x7f84eec092e0>,
#   <matplotlib.patches.Wedge at 0x7f84eec097c0>,
#   <matplotlib.patches.Wedge at 0x7f84eec09ca0>,
#   <matplotlib.patches.Wedge at 0x7f84eec161c0>,
#   <matplotlib.patches.Wedge at 0x7f84eec166a0>,
#   <matplotlib.patches.Wedge at 0x7f84eec16b80>,
#   <matplotlib.patches.Wedge at 0x7f84eec240a0>,
#   <matplotlib.patches.Wedge at 0x7f84eec24580>,
#   <matplotlib.patches.Wedge at 0x7f84eec24a60>,
#   <matplotlib.patches.Wedge at 0x7f84eec24f40>,
#   <matplotlib.patches.Wedge at 0x7f84eec30460>,
#   <matplotlib.patches.Wedge at 0x7f84eec30940>,
#   <matplotlib.patches.Wedge at 0x7f84eec30e20>,
#   <matplotlib.patches.Wedge at 0x7f84eec3c340>,
#   <matplotlib.patches.Wedge at 0x7f84eec3c820>,
#   <matplotlib.patches.Wedge at 0x7f84eec3cd00>,
#   <matplotlib.patches.Wedge at 0x7f84eec49220>,
#   <matplotlib.patches.Wedge at 0x7f84eec49700>,
#   <matplotlib.patches.Wedge at 0x7f84eec49be0>,
#   <matplotlib.patches.Wedge at 0x7f84eec54100>,
#   <matplotlib.patches.Wedge at 0x7f84eec545e0>,
#   <matplotlib.patches.Wedge at 0x7f84eec54ac0>,
#   <matplotlib.patches.Wedge at 0x7f84eec54fa0>,
#   <matplotlib.patches.Wedge at 0x7f84eeb624c0>,
#   <matplotlib.patches.Wedge at 0x7f84eeb629a0>,
#   <matplotlib.patches.Wedge at 0x7f84eeb62e80>,
#   <matplotlib.patches.Wedge at 0x7f84eeb6e3a0>,
#   <matplotlib.patches.Wedge at 0x7f84eeb6e880>,
#   <matplotlib.patches.Wedge at 0x7f84eeb6ed60>,
#   <matplotlib.patches.Wedge at 0x7f84eeb7a280>,
#   <matplotlib.patches.Wedge at 0x7f84eeb7a760>,
#   <matplotlib.patches.Wedge at 0x7f84eeb7ac40>,
#   <matplotlib.patches.Wedge at 0x7f84eeb86160>,
#   <matplotlib.patches.Wedge at 0x7f84eeb86640>,
#   <matplotlib.patches.Wedge at 0x7f84eeb86b20>,
#   <matplotlib.patches.Wedge at 0x7f84eeb94040>,
#   <matplotlib.patches.Wedge at 0x7f84eeb94520>,
#   <matplotlib.patches.Wedge at 0x7f84eeb94a00>,
#   <matplotlib.patches.Wedge at 0x7f84eeb94ee0>,
#   <matplotlib.patches.Wedge at 0x7f84eeb20400>,
#   <matplotlib.patches.Wedge at 0x7f84eeb208e0>,
#   <matplotlib.patches.Wedge at 0x7f84eeb20dc0>,
#   <matplotlib.patches.Wedge at 0x7f84eeb2c2e0>,
#   <matplotlib.patches.Wedge at 0x7f84eeb2c7c0>,
#   <matplotlib.patches.Wedge at 0x7f84eeb2cca0>,
#   <matplotlib.patches.Wedge at 0x7f84eeb391c0>,
#   <matplotlib.patches.Wedge at 0x7f84eeb396a0>,
#   <matplotlib.patches.Wedge at 0x7f84eeb39b80>,
#   <matplotlib.patches.Wedge at 0x7f84eeb460a0>,
#   <matplotlib.patches.Wedge at 0x7f84eeb46580>,
#   <matplotlib.patches.Wedge at 0x7f84eeb46a60>,
#   <matplotlib.patches.Wedge at 0x7f84eeb46f40>,
#   <matplotlib.patches.Wedge at 0x7f84eeb53460>,
#   <matplotlib.patches.Wedge at 0x7f84eeb53940>,
#   <matplotlib.patches.Wedge at 0x7f84eeb53e20>,
#   <matplotlib.patches.Wedge at 0x7f84eeadf340>,
#   <matplotlib.patches.Wedge at 0x7f84eeadf820>,
#   <matplotlib.patches.Wedge at 0x7f84eeadfd00>,
#   <matplotlib.patches.Wedge at 0x7f84eeaed220>,
#   <matplotlib.patches.Wedge at 0x7f84eeaed700>,
#   <matplotlib.patches.Wedge at 0x7f84eeaedbe0>,
#   <matplotlib.patches.Wedge at 0x7f84eeafb100>,
#   <matplotlib.patches.Wedge at 0x7f84eeafb5e0>,
#   <matplotlib.patches.Wedge at 0x7f84eeafbac0>,
#   <matplotlib.patches.Wedge at 0x7f84eeafbfa0>,
#   <matplotlib.patches.Wedge at 0x7f84eeb084c0>,
#   <matplotlib.patches.Wedge at 0x7f84eeb089a0>,
#   <matplotlib.patches.Wedge at 0x7f84eeb08e80>,
#   <matplotlib.patches.Wedge at 0x7f84eeb133a0>,
#   <matplotlib.patches.Wedge at 0x7f84eeb13880>,
#   <matplotlib.patches.Wedge at 0x7f84eeb13d60>,
#   <matplotlib.patches.Wedge at 0x7f84eeaa3280>,
#   <matplotlib.patches.Wedge at 0x7f84eeaa3760>,
#   <matplotlib.patches.Wedge at 0x7f84eeaa3c40>,
#   <matplotlib.patches.Wedge at 0x7f84eeab0160>,
#   <matplotlib.patches.Wedge at 0x7f84eeab0640>,
#   <matplotlib.patches.Wedge at 0x7f84eeab0b20>,
#   <matplotlib.patches.Wedge at 0x7f84eeabc040>,
#   <matplotlib.patches.Wedge at 0x7f84eeabc520>,
#   <matplotlib.patches.Wedge at 0x7f84eeabca00>,
#   <matplotlib.patches.Wedge at 0x7f84eeabcee0>,
#   <matplotlib.patches.Wedge at 0x7f84eeaca400>,
#   <matplotlib.patches.Wedge at 0x7f84eeaca8e0>,
#   <matplotlib.patches.Wedge at 0x7f84eeacadc0>,
#   <matplotlib.patches.Wedge at 0x7f84eea562e0>,
#   <matplotlib.patches.Wedge at 0x7f84eea567c0>,
#   <matplotlib.patches.Wedge at 0x7f84eea56ca0>,
#   <matplotlib.patches.Wedge at 0x7f84eea641c0>,
#   <matplotlib.patches.Wedge at 0x7f84eea646a0>,
#   <matplotlib.patches.Wedge at 0x7f84eea64b80>,
#   <matplotlib.patches.Wedge at 0x7f84eea720a0>,
#   <matplotlib.patches.Wedge at 0x7f84eea72580>,
#   <matplotlib.patches.Wedge at 0x7f84eea72a60>,
#   <matplotlib.patches.Wedge at 0x7f84eea72f40>,
#   <matplotlib.patches.Wedge at 0x7f84eea7f460>,
#   <matplotlib.patches.Wedge at 0x7f84eea7f940>,
#   <matplotlib.patches.Wedge at 0x7f84eea7fe20>,
#   <matplotlib.patches.Wedge at 0x7f84eea8c340>,
#   <matplotlib.patches.Wedge at 0x7f84eea8c820>,
#   <matplotlib.patches.Wedge at 0x7f84eea8cd00>,
#   <matplotlib.patches.Wedge at 0x7f84eea1a220>,
#   <matplotlib.patches.Wedge at 0x7f84eea1a700>,
#   <matplotlib.patches.Wedge at 0x7f84eea1abe0>,
#   <matplotlib.patches.Wedge at 0x7f84eea26100>,
#   <matplotlib.patches.Wedge at 0x7f84eea265e0>,
#   <matplotlib.patches.Wedge at 0x7f84eea26ac0>,
#   <matplotlib.patches.Wedge at 0x7f84eea26fa0>,
#   <matplotlib.patches.Wedge at 0x7f84eea354c0>,
#   <matplotlib.patches.Wedge at 0x7f84eea359a0>,
#   <matplotlib.patches.Wedge at 0x7f84eea35e80>,
#   <matplotlib.patches.Wedge at 0x7f84eea413a0>,
#   <matplotlib.patches.Wedge at 0x7f84eea41880>,
#   <matplotlib.patches.Wedge at 0x7f84eea41d60>,
#   <matplotlib.patches.Wedge at 0x7f84eea4e280>,
#   <matplotlib.patches.Wedge at 0x7f84eea4e760>,
#   <matplotlib.patches.Wedge at 0x7f84eea4ec40>,
#   <matplotlib.patches.Wedge at 0x7f84ee9dd160>,
#   <matplotlib.patches.Wedge at 0x7f84ee9dd640>,
#   <matplotlib.patches.Wedge at 0x7f84ee9ddb20>,
#   <matplotlib.patches.Wedge at 0x7f84ee9e8040>,
#   <matplotlib.patches.Wedge at 0x7f84ee9e8520>,
#   <matplotlib.patches.Wedge at 0x7f84ee9e8a00>,
#   <matplotlib.patches.Wedge at 0x7f84ee9e8ee0>,
#   <matplotlib.patches.Wedge at 0x7f84ee9f7400>,
#   <matplotlib.patches.Wedge at 0x7f84ee9f78e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee9f7dc0>,
#   <matplotlib.patches.Wedge at 0x7f84eea032e0>,
#   <matplotlib.patches.Wedge at 0x7f84eea037c0>,
#   <matplotlib.patches.Wedge at 0x7f84eea03ca0>,
#   <matplotlib.patches.Wedge at 0x7f84eea101c0>,
#   <matplotlib.patches.Wedge at 0x7f84eea106a0>,
#   <matplotlib.patches.Wedge at 0x7f84eea10b80>,
#   <matplotlib.patches.Wedge at 0x7f84ee99f0a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee99f580>,
#   <matplotlib.patches.Wedge at 0x7f84ee99fa60>,
#   <matplotlib.patches.Wedge at 0x7f84ee99ff40>,
#   <matplotlib.patches.Wedge at 0x7f84ee9ab460>,
#   <matplotlib.patches.Wedge at 0x7f84ee9ab940>,
#   <matplotlib.patches.Wedge at 0x7f84ee9abe20>,
#   <matplotlib.patches.Wedge at 0x7f84ee9b8340>,
#   <matplotlib.patches.Wedge at 0x7f84ee9b8820>,
#   <matplotlib.patches.Wedge at 0x7f84ee9b8d00>,
#   <matplotlib.patches.Wedge at 0x7f84ee9c7220>,
#   <matplotlib.patches.Wedge at 0x7f84ee9c7700>,
#   <matplotlib.patches.Wedge at 0x7f84ee9c7be0>,
#   <matplotlib.patches.Wedge at 0x7f84ee9d3100>,
#   <matplotlib.patches.Wedge at 0x7f84ee9d35e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee9d3ac0>,
#   <matplotlib.patches.Wedge at 0x7f84ee9d3fa0>,
#   <matplotlib.patches.Wedge at 0x7f84ee9604c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee9609a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee960e80>,
#   <matplotlib.patches.Wedge at 0x7f84ee96f3a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee96f880>,
#   <matplotlib.patches.Wedge at 0x7f84ee96fd60>,
#   <matplotlib.patches.Wedge at 0x7f84ee97c280>,
#   <matplotlib.patches.Wedge at 0x7f84ee97c760>,
#   <matplotlib.patches.Wedge at 0x7f84ee97cc40>,
#   <matplotlib.patches.Wedge at 0x7f84ee988160>,
#   <matplotlib.patches.Wedge at 0x7f84ee988640>,
#   <matplotlib.patches.Wedge at 0x7f84ee988b20>,
#   <matplotlib.patches.Wedge at 0x7f84ee994040>,
#   <matplotlib.patches.Wedge at 0x7f84ee994520>,
#   <matplotlib.patches.Wedge at 0x7f84ee994a00>,
#   <matplotlib.patches.Wedge at 0x7f84ee994ee0>,
#   <matplotlib.patches.Wedge at 0x7f84ee924400>,
#   <matplotlib.patches.Wedge at 0x7f84ee9248e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee924dc0>,
#   <matplotlib.patches.Wedge at 0x7f84ee9312e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee9317c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee931ca0>,
#   <matplotlib.patches.Wedge at 0x7f84ee93c1c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee93c6a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee93cb80>,
#   <matplotlib.patches.Wedge at 0x7f84ee94b0a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee94b580>,
#   <matplotlib.patches.Wedge at 0x7f84ee94ba60>,
#   <matplotlib.patches.Wedge at 0x7f84ee94bf40>,
#   <matplotlib.patches.Wedge at 0x7f84ee8d9460>,
#   <matplotlib.patches.Wedge at 0x7f84ee8d9940>,
#   <matplotlib.patches.Wedge at 0x7f84ee8d9e20>,
#   <matplotlib.patches.Wedge at 0x7f84ee8e5340>,
#   <matplotlib.patches.Wedge at 0x7f84ee8e5820>,
#   <matplotlib.patches.Wedge at 0x7f84ee8e5d00>,
#   <matplotlib.patches.Wedge at 0x7f84ee8f3220>,
#   <matplotlib.patches.Wedge at 0x7f84ee8f3700>,
#   <matplotlib.patches.Wedge at 0x7f84ee8f3be0>,
#   <matplotlib.patches.Wedge at 0x7f84ee900100>,
#   <matplotlib.patches.Wedge at 0x7f84ee9005e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee900ac0>,
#   <matplotlib.patches.Wedge at 0x7f84ee900fa0>,
#   <matplotlib.patches.Wedge at 0x7f84ee90e4c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee90e9a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee90ee80>,
#   <matplotlib.patches.Wedge at 0x7f84ee89a3a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee89a880>,
#   <matplotlib.patches.Wedge at 0x7f84ee89ad60>,
#   <matplotlib.patches.Wedge at 0x7f84ee8a9280>,
#   <matplotlib.patches.Wedge at 0x7f84ee8a9760>,
#   <matplotlib.patches.Wedge at 0x7f84ee8a9c40>,
#   <matplotlib.patches.Wedge at 0x7f84ee8b5160>,
#   <matplotlib.patches.Wedge at 0x7f84ee8b5640>,
#   <matplotlib.patches.Wedge at 0x7f84ee8b5b20>,
#   <matplotlib.patches.Wedge at 0x7f84ee8c1040>,
#   <matplotlib.patches.Wedge at 0x7f84ee8c1520>,
#   <matplotlib.patches.Wedge at 0x7f84ee8c1a00>,
#   <matplotlib.patches.Wedge at 0x7f84ee8c1ee0>,
#   <matplotlib.patches.Wedge at 0x7f84ee8d0400>,
#   <matplotlib.patches.Wedge at 0x7f84ee8d08e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee8d0dc0>,
#   <matplotlib.patches.Wedge at 0x7f84ee85d2e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee85d7c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee85dca0>,
#   <matplotlib.patches.Wedge at 0x7f84ee86a1c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee86a6a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee86ab80>,
#   <matplotlib.patches.Wedge at 0x7f84ee8780a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee878580>,
#   <matplotlib.patches.Wedge at 0x7f84ee878a60>,
#   <matplotlib.patches.Wedge at 0x7f84ee878f40>,
#   <matplotlib.patches.Wedge at 0x7f84ee885460>,
#   <matplotlib.patches.Wedge at 0x7f84ee885940>,
#   <matplotlib.patches.Wedge at 0x7f84ee885e20>,
#   <matplotlib.patches.Wedge at 0x7f84ee892340>,
#   <matplotlib.patches.Wedge at 0x7f84ee892820>,
#   <matplotlib.patches.Wedge at 0x7f84ee892d00>,
#   <matplotlib.patches.Wedge at 0x7f84ee820220>,
#   <matplotlib.patches.Wedge at 0x7f84ee820700>,
#   <matplotlib.patches.Wedge at 0x7f84ee820be0>,
#   <matplotlib.patches.Wedge at 0x7f84ee82c100>,
#   <matplotlib.patches.Wedge at 0x7f84ee82c5e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee82cac0>,
#   <matplotlib.patches.Wedge at 0x7f84ee82cfa0>,
#   <matplotlib.patches.Wedge at 0x7f84ee83a4c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee83a9a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee83ae80>,
#   <matplotlib.patches.Wedge at 0x7f84ee8473a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee847880>,
#   <matplotlib.patches.Wedge at 0x7f84ee847d60>,
#   <matplotlib.patches.Wedge at 0x7f84ee854280>,
#   <matplotlib.patches.Wedge at 0x7f84ee854760>,
#   <matplotlib.patches.Wedge at 0x7f84ee854c40>,
#   <matplotlib.patches.Wedge at 0x7f84ee7e4160>,
#   <matplotlib.patches.Wedge at 0x7f84ee7e4640>,
#   <matplotlib.patches.Wedge at 0x7f84ee7e4b20>,
#   <matplotlib.patches.Wedge at 0x7f84ee7ee040>,
#   <matplotlib.patches.Wedge at 0x7f84ee7ee520>,
#   <matplotlib.patches.Wedge at 0x7f84ee7eea00>,
#   <matplotlib.patches.Wedge at 0x7f84ee7eeee0>,
#   <matplotlib.patches.Wedge at 0x7f84ee7fd400>,
#   <matplotlib.patches.Wedge at 0x7f84ee7fd8e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee7fddc0>,
#   <matplotlib.patches.Wedge at 0x7f84ee8082e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee8087c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee808ca0>,
#   <matplotlib.patches.Wedge at 0x7f84ee7971c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee7976a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee797b80>,
#   <matplotlib.patches.Wedge at 0x7f84ee7a50a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee7a5580>,
#   <matplotlib.patches.Wedge at 0x7f84ee7a5a60>,
#   <matplotlib.patches.Wedge at 0x7f84ee7a5f40>,
#   <matplotlib.patches.Wedge at 0x7f84ee7b1460>,
#   <matplotlib.patches.Wedge at 0x7f84ee7b1940>,
#   <matplotlib.patches.Wedge at 0x7f84ee7b1e20>,
#   <matplotlib.patches.Wedge at 0x7f84ee7bd340>,
#   <matplotlib.patches.Wedge at 0x7f84ee7bd820>,
#   <matplotlib.patches.Wedge at 0x7f84ee7bdd00>,
#   <matplotlib.patches.Wedge at 0x7f84ee7ce220>,
#   <matplotlib.patches.Wedge at 0x7f84ee7ce700>,
#   <matplotlib.patches.Wedge at 0x7f84ee7cebe0>,
#   <matplotlib.patches.Wedge at 0x7f84ee75a100>,
#   <matplotlib.patches.Wedge at 0x7f84ee75a5e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee75aac0>,
#   <matplotlib.patches.Wedge at 0x7f84ee75afa0>,
#   <matplotlib.patches.Wedge at 0x7f84ee7654c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee7659a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee765e80>,
#   <matplotlib.patches.Wedge at 0x7f84ee7743a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee774880>,
#   <matplotlib.patches.Wedge at 0x7f84ee774d60>,
#   <matplotlib.patches.Wedge at 0x7f84ee782280>,
#   <matplotlib.patches.Wedge at 0x7f84ee782760>,
#   <matplotlib.patches.Wedge at 0x7f84ee782c40>,
#   <matplotlib.patches.Wedge at 0x7f84ee78e160>,
#   <matplotlib.patches.Wedge at 0x7f84ee78e640>,
#   <matplotlib.patches.Wedge at 0x7f84ee78eb20>,
#   <matplotlib.patches.Wedge at 0x7f84ee71b040>,
#   <matplotlib.patches.Wedge at 0x7f84ee71b520>,
#   <matplotlib.patches.Wedge at 0x7f84ee71ba00>,
#   <matplotlib.patches.Wedge at 0x7f84ee71bee0>,
#   <matplotlib.patches.Wedge at 0x7f84ee729400>,
#   <matplotlib.patches.Wedge at 0x7f84ee7298e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee729dc0>,
#   <matplotlib.patches.Wedge at 0x7f84ee7362e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee7367c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee736ca0>,
#   <matplotlib.patches.Wedge at 0x7f84ee7431c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee7436a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee743b80>,
#   <matplotlib.patches.Wedge at 0x7f84ee7520a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee752580>,
#   <matplotlib.patches.Wedge at 0x7f84ee752a60>,
#   <matplotlib.patches.Wedge at 0x7f84ee752f40>,
#   <matplotlib.patches.Wedge at 0x7f84ee6de460>,
#   <matplotlib.patches.Wedge at 0x7f84ee6de940>,
#   <matplotlib.patches.Wedge at 0x7f84ee6dee20>,
#   <matplotlib.patches.Wedge at 0x7f84ee6eb340>,
#   <matplotlib.patches.Wedge at 0x7f84ee6eb820>,
#   <matplotlib.patches.Wedge at 0x7f84ee6ebd00>,
#   <matplotlib.patches.Wedge at 0x7f84ee6f9220>,
#   <matplotlib.patches.Wedge at 0x7f84ee6f9700>,
#   <matplotlib.patches.Wedge at 0x7f84ee6f9be0>,
#   <matplotlib.patches.Wedge at 0x7f84ee707100>,
#   <matplotlib.patches.Wedge at 0x7f84ee7075e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee707ac0>,
#   <matplotlib.patches.Wedge at 0x7f84ee707fa0>,
#   <matplotlib.patches.Wedge at 0x7f84ee7134c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee7139a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee713e80>,
#   <matplotlib.patches.Wedge at 0x7f84ee6a03a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee6a0880>,
#   <matplotlib.patches.Wedge at 0x7f84ee6a0d60>,
#   <matplotlib.patches.Wedge at 0x7f84ee6af280>,
#   <matplotlib.patches.Wedge at 0x7f84ee6af760>,
#   <matplotlib.patches.Wedge at 0x7f84ee6afc40>,
#   <matplotlib.patches.Wedge at 0x7f84ee6bb160>,
#   <matplotlib.patches.Wedge at 0x7f84ee6bb640>,
#   <matplotlib.patches.Wedge at 0x7f84ee6bbb20>,
#   <matplotlib.patches.Wedge at 0x7f84ee6c7040>,
#   <matplotlib.patches.Wedge at 0x7f84ee6c7520>,
#   <matplotlib.patches.Wedge at 0x7f84ee6c7a00>,
#   <matplotlib.patches.Wedge at 0x7f84ee6c7ee0>,
#   <matplotlib.patches.Wedge at 0x7f84ee656400>,
#   <matplotlib.patches.Wedge at 0x7f84ee6568e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee656dc0>,
#   <matplotlib.patches.Wedge at 0x7f84ee6622e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee6627c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee662ca0>,
#   <matplotlib.patches.Wedge at 0x7f84ee6701c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee6706a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee670b80>,
#   <matplotlib.patches.Wedge at 0x7f84ee67e0a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee67e580>,
#   <matplotlib.patches.Wedge at 0x7f84ee67ea60>,
#   <matplotlib.patches.Wedge at 0x7f84ee67ef40>,
#   <matplotlib.patches.Wedge at 0x7f84ee68b460>,
#   <matplotlib.patches.Wedge at 0x7f84ee68b940>,
#   <matplotlib.patches.Wedge at 0x7f84ee68be20>,
#   <matplotlib.patches.Wedge at 0x7f84ee618340>,
#   <matplotlib.patches.Wedge at 0x7f84ee618820>,
#   <matplotlib.patches.Wedge at 0x7f84ee618d00>,
#   <matplotlib.patches.Wedge at 0x7f84ee626220>,
#   <matplotlib.patches.Wedge at 0x7f84ee626700>,
#   <matplotlib.patches.Wedge at 0x7f84ee626be0>,
#   <matplotlib.patches.Wedge at 0x7f84ee632100>,
#   <matplotlib.patches.Wedge at 0x7f84ee6325e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee632ac0>,
#   <matplotlib.patches.Wedge at 0x7f84ee632fa0>,
#   <matplotlib.patches.Wedge at 0x7f84ee6414c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee6419a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee641e80>,
#   <matplotlib.patches.Wedge at 0x7f84ee64d3a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee64d880>,
#   <matplotlib.patches.Wedge at 0x7f84ee64dd60>,
#   <matplotlib.patches.Wedge at 0x7f84ee5da280>,
#   <matplotlib.patches.Wedge at 0x7f84ee5da760>,
#   <matplotlib.patches.Wedge at 0x7f84ee5dac40>,
#   <matplotlib.patches.Wedge at 0x7f84ee5e8160>,
#   <matplotlib.patches.Wedge at 0x7f84ee5e8640>,
#   <matplotlib.patches.Wedge at 0x7f84ee5e8b20>,
#   <matplotlib.patches.Wedge at 0x7f84ee5f5040>,
#   <matplotlib.patches.Wedge at 0x7f84ee5f5520>,
#   <matplotlib.patches.Wedge at 0x7f84ee5f5a00>,
#   <matplotlib.patches.Wedge at 0x7f84ee5f5ee0>,
#   <matplotlib.patches.Wedge at 0x7f84ee603400>,
#   <matplotlib.patches.Wedge at 0x7f84ee6038e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee603dc0>,
#   <matplotlib.patches.Wedge at 0x7f84ee60e2e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee60e7c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee60eca0>,
#   <matplotlib.patches.Wedge at 0x7f84ee59c1c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee59c6a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee59cb80>,
#   <matplotlib.patches.Wedge at 0x7f84ee5ac0a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee5ac580>,
#   <matplotlib.patches.Wedge at 0x7f84ee5aca60>,
#   <matplotlib.patches.Wedge at 0x7f84ee5acf40>,
#   <matplotlib.patches.Wedge at 0x7f84ee5b7460>,
#   <matplotlib.patches.Wedge at 0x7f84ee5b7940>,
#   <matplotlib.patches.Wedge at 0x7f84ee5b7e20>,
#   <matplotlib.patches.Wedge at 0x7f84ee5c3340>,
#   <matplotlib.patches.Wedge at 0x7f84ee5c3820>,
#   <matplotlib.patches.Wedge at 0x7f84ee5c3d00>,
#   <matplotlib.patches.Wedge at 0x7f84ee5d3220>,
#   <matplotlib.patches.Wedge at 0x7f84ee5d3700>,
#   <matplotlib.patches.Wedge at 0x7f84ee5d3be0>,
#   <matplotlib.patches.Wedge at 0x7f84ee55f100>,
#   <matplotlib.patches.Wedge at 0x7f84ee55f5e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee55fac0>,
#   <matplotlib.patches.Wedge at 0x7f84ee55ffa0>,
#   <matplotlib.patches.Wedge at 0x7f84ee56c4c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee56c9a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee56ce80>,
#   <matplotlib.patches.Wedge at 0x7f84ee57a3a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee57a880>,
#   <matplotlib.patches.Wedge at 0x7f84ee57ad60>,
#   <matplotlib.patches.Wedge at 0x7f84ee586280>,
#   <matplotlib.patches.Wedge at 0x7f84ee586760>,
#   <matplotlib.patches.Wedge at 0x7f84ee586c40>,
#   <matplotlib.patches.Wedge at 0x7f84ee594160>,
#   <matplotlib.patches.Wedge at 0x7f84ee594640>,
#   <matplotlib.patches.Wedge at 0x7f84ee594b20>,
#   <matplotlib.patches.Wedge at 0x7f84ee521040>,
#   <matplotlib.patches.Wedge at 0x7f84ee521520>,
#   <matplotlib.patches.Wedge at 0x7f84ee521a00>,
#   <matplotlib.patches.Wedge at 0x7f84ee521ee0>,
#   <matplotlib.patches.Wedge at 0x7f84ee530400>,
#   <matplotlib.patches.Wedge at 0x7f84ee5308e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee530dc0>,
#   <matplotlib.patches.Wedge at 0x7f84ee53b2e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee53b7c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee53bca0>,
#   <matplotlib.patches.Wedge at 0x7f84ee5491c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee5496a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee549b80>,
#   <matplotlib.patches.Wedge at 0x7f84ee4d80a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee4d8580>,
#   <matplotlib.patches.Wedge at 0x7f84ee4d8a60>,
#   <matplotlib.patches.Wedge at 0x7f84ee4d8f40>,
#   <matplotlib.patches.Wedge at 0x7f84ee4e4460>,
#   <matplotlib.patches.Wedge at 0x7f84ee4e4940>,
#   <matplotlib.patches.Wedge at 0x7f84ee4e4e20>,
#   <matplotlib.patches.Wedge at 0x7f84ee4f0340>,
#   <matplotlib.patches.Wedge at 0x7f84ee4f0820>,
#   <matplotlib.patches.Wedge at 0x7f84ee4f0d00>,
#   <matplotlib.patches.Wedge at 0x7f84ee4ff220>,
#   <matplotlib.patches.Wedge at 0x7f84ee4ff700>,
#   <matplotlib.patches.Wedge at 0x7f84ee4ffbe0>,
#   <matplotlib.patches.Wedge at 0x7f84ee50c100>,
#   <matplotlib.patches.Wedge at 0x7f84ee50c5e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee50cac0>,
#   <matplotlib.patches.Wedge at 0x7f84ee50cfa0>,
#   <matplotlib.patches.Wedge at 0x7f84ee4994c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee4999a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee499e80>,
#   <matplotlib.patches.Wedge at 0x7f84ee4a63a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee4a6880>,
#   <matplotlib.patches.Wedge at 0x7f84ee4a6d60>,
#   <matplotlib.patches.Wedge at 0x7f84ee4b4280>,
#   <matplotlib.patches.Wedge at 0x7f84ee4b4760>,
#   <matplotlib.patches.Wedge at 0x7f84ee4b4c40>,
#   <matplotlib.patches.Wedge at 0x7f84ee4c1160>,
#   <matplotlib.patches.Wedge at 0x7f84ee4c1640>,
#   <matplotlib.patches.Wedge at 0x7f84ee4c1b20>,
#   <matplotlib.patches.Wedge at 0x7f84ee4cd040>,
#   <matplotlib.patches.Wedge at 0x7f84ee4cd520>,
#   <matplotlib.patches.Wedge at 0x7f84ee4cda00>,
#   <matplotlib.patches.Wedge at 0x7f84ee4cdee0>,
#   <matplotlib.patches.Wedge at 0x7f84ee45b400>,
#   <matplotlib.patches.Wedge at 0x7f84ee45b8e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee45bdc0>,
#   <matplotlib.patches.Wedge at 0x7f84ee4682e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee4687c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee468ca0>,
#   <matplotlib.patches.Wedge at 0x7f84ee4761c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee4766a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee476b80>,
#   <matplotlib.patches.Wedge at 0x7f84ee4830a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee483580>,
#   <matplotlib.patches.Wedge at 0x7f84ee483a60>,
#   <matplotlib.patches.Wedge at 0x7f84ee483f40>,
#   <matplotlib.patches.Wedge at 0x7f84ee490460>,
#   <matplotlib.patches.Wedge at 0x7f84ee490940>,
#   <matplotlib.patches.Wedge at 0x7f84ee490e20>,
#   <matplotlib.patches.Wedge at 0x7f84ee41f340>,
#   <matplotlib.patches.Wedge at 0x7f84ee41f820>,
#   <matplotlib.patches.Wedge at 0x7f84ee41fd00>,
#   <matplotlib.patches.Wedge at 0x7f84ee42b220>,
#   <matplotlib.patches.Wedge at 0x7f84ee42b700>,
#   <matplotlib.patches.Wedge at 0x7f84ee42bbe0>,
#   <matplotlib.patches.Wedge at 0x7f84ee437100>,
#   <matplotlib.patches.Wedge at 0x7f84ee4375e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee437ac0>,
#   <matplotlib.patches.Wedge at 0x7f84ee437fa0>,
#   <matplotlib.patches.Wedge at 0x7f84ee4464c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee4469a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee446e80>,
#   <matplotlib.patches.Wedge at 0x7f84ee4543a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee454880>,
#   <matplotlib.patches.Wedge at 0x7f84ee454d60>,
#   <matplotlib.patches.Wedge at 0x7f84ee3df280>,
#   <matplotlib.patches.Wedge at 0x7f84ee3df760>,
#   <matplotlib.patches.Wedge at 0x7f84ee3dfc40>,
#   <matplotlib.patches.Wedge at 0x7f84ee3ee160>,
#   <matplotlib.patches.Wedge at 0x7f84ee3ee640>,
#   <matplotlib.patches.Wedge at 0x7f84ee3eeb20>,
#   <matplotlib.patches.Wedge at 0x7f84ee3fa040>,
#   <matplotlib.patches.Wedge at 0x7f84ee3fa520>,
#   <matplotlib.patches.Wedge at 0x7f84ee3faa00>,
#   <matplotlib.patches.Wedge at 0x7f84ee3faee0>,
#   <matplotlib.patches.Wedge at 0x7f84ee408400>,
#   <matplotlib.patches.Wedge at 0x7f84ee4088e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee408dc0>,
#   <matplotlib.patches.Wedge at 0x7f84ee4142e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee4147c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee414ca0>,
#   <matplotlib.patches.Wedge at 0x7f84ee3a21c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee3a26a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee3a2b80>,
#   <matplotlib.patches.Wedge at 0x7f84ee3b00a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee3b0580>,
#   <matplotlib.patches.Wedge at 0x7f84ee3b0a60>,
#   <matplotlib.patches.Wedge at 0x7f84ee3b0f40>,
#   <matplotlib.patches.Wedge at 0x7f84ee3bc460>,
#   <matplotlib.patches.Wedge at 0x7f84ee3bc940>,
#   <matplotlib.patches.Wedge at 0x7f84ee3bce20>,
#   <matplotlib.patches.Wedge at 0x7f84ee3ca340>,
#   <matplotlib.patches.Wedge at 0x7f84ee3ca820>,
#   <matplotlib.patches.Wedge at 0x7f84ee3cad00>,
#   <matplotlib.patches.Wedge at 0x7f84ee359220>,
#   <matplotlib.patches.Wedge at 0x7f84ee359700>,
#   <matplotlib.patches.Wedge at 0x7f84ee359be0>,
#   <matplotlib.patches.Wedge at 0x7f84ee364100>,
#   <matplotlib.patches.Wedge at 0x7f84ee3645e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee364ac0>,
#   <matplotlib.patches.Wedge at 0x7f84ee364fa0>,
#   <matplotlib.patches.Wedge at 0x7f84ee3714c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee3719a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee371e80>,
#   <matplotlib.patches.Wedge at 0x7f84ee3803a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee380880>,
#   <matplotlib.patches.Wedge at 0x7f84ee380d60>,
#   <matplotlib.patches.Wedge at 0x7f84ee38d280>,
#   <matplotlib.patches.Wedge at 0x7f84ee38d760>,
#   <matplotlib.patches.Wedge at 0x7f84ee38dc40>,
#   <matplotlib.patches.Wedge at 0x7f84ee319160>,
#   <matplotlib.patches.Wedge at 0x7f84ee319640>,
#   <matplotlib.patches.Wedge at 0x7f84ee319b20>,
#   <matplotlib.patches.Wedge at 0x7f84ee325040>,
#   <matplotlib.patches.Wedge at 0x7f84ee325520>,
#   <matplotlib.patches.Wedge at 0x7f84ee325a00>,
#   <matplotlib.patches.Wedge at 0x7f84ee325ee0>,
#   <matplotlib.patches.Wedge at 0x7f84ee335400>,
#   <matplotlib.patches.Wedge at 0x7f84ee3358e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee335dc0>,
#   <matplotlib.patches.Wedge at 0x7f84ee3422e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee3427c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee342ca0>,
#   <matplotlib.patches.Wedge at 0x7f84ee34f1c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee34f6a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee34fb80>,
#   <matplotlib.patches.Wedge at 0x7f84ee2dc0a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee2dc580>,
#   <matplotlib.patches.Wedge at 0x7f84ee2dca60>,
#   <matplotlib.patches.Wedge at 0x7f84ee2dcf40>,
#   <matplotlib.patches.Wedge at 0x7f84ee2ea460>,
#   <matplotlib.patches.Wedge at 0x7f84ee2ea940>,
#   <matplotlib.patches.Wedge at 0x7f84ee2eae20>,
#   <matplotlib.patches.Wedge at 0x7f84ee2f7340>,
#   <matplotlib.patches.Wedge at 0x7f84ee2f7820>,
#   <matplotlib.patches.Wedge at 0x7f84ee2f7d00>,
#   <matplotlib.patches.Wedge at 0x7f84ee304220>,
#   <matplotlib.patches.Wedge at 0x7f84ee304700>,
#   <matplotlib.patches.Wedge at 0x7f84ee304be0>,
#   <matplotlib.patches.Wedge at 0x7f84ee311100>,
#   <matplotlib.patches.Wedge at 0x7f84ee3115e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee311ac0>,
#   <matplotlib.patches.Wedge at 0x7f84ee311fa0>,
#   <matplotlib.patches.Wedge at 0x7f84ee29f4c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee29f9a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee29fe80>,
#   <matplotlib.patches.Wedge at 0x7f84ee2ab3a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee2ab880>,
#   <matplotlib.patches.Wedge at 0x7f84ee2abd60>,
#   <matplotlib.patches.Wedge at 0x7f84ee2ba280>,
#   <matplotlib.patches.Wedge at 0x7f84ee2ba760>,
#   <matplotlib.patches.Wedge at 0x7f84ee2bac40>,
#   <matplotlib.patches.Wedge at 0x7f84ee2c6160>,
#   <matplotlib.patches.Wedge at 0x7f84ee2c6640>,
#   <matplotlib.patches.Wedge at 0x7f84ee2c6b20>,
#   <matplotlib.patches.Wedge at 0x7f84ee2d2040>,
#   <matplotlib.patches.Wedge at 0x7f84ee2d2520>,
#   <matplotlib.patches.Wedge at 0x7f84ee2d2a00>,
#   <matplotlib.patches.Wedge at 0x7f84ee2d2ee0>,
#   <matplotlib.patches.Wedge at 0x7f84ee261400>,
#   <matplotlib.patches.Wedge at 0x7f84ee2618e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee261dc0>,
#   <matplotlib.patches.Wedge at 0x7f84ee26e2e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee26e7c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee26eca0>,
#   <matplotlib.patches.Wedge at 0x7f84ee27c1c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee27c6a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee27cb80>,
#   <matplotlib.patches.Wedge at 0x7f84ee2890a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee289580>,
#   <matplotlib.patches.Wedge at 0x7f84ee289a60>,
#   <matplotlib.patches.Wedge at 0x7f84ee289f40>,
#   <matplotlib.patches.Wedge at 0x7f84ee216460>,
#   <matplotlib.patches.Wedge at 0x7f84ee216940>,
#   <matplotlib.patches.Wedge at 0x7f84ee216e20>,
#   <matplotlib.patches.Wedge at 0x7f84ee224340>,
#   <matplotlib.patches.Wedge at 0x7f84ee224820>,
#   <matplotlib.patches.Wedge at 0x7f84ee224d00>,
#   <matplotlib.patches.Wedge at 0x7f84ee232220>,
#   <matplotlib.patches.Wedge at 0x7f84ee232700>,
#   <matplotlib.patches.Wedge at 0x7f84ee232be0>,
#   <matplotlib.patches.Wedge at 0x7f84ee23e100>,
#   <matplotlib.patches.Wedge at 0x7f84ee23e5e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee23eac0>,
#   <matplotlib.patches.Wedge at 0x7f84ee23efa0>,
#   <matplotlib.patches.Wedge at 0x7f84ee24c4c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee24c9a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee24ce80>,
#   <matplotlib.patches.Wedge at 0x7f84ee1d83a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee1d8880>,
#   <matplotlib.patches.Wedge at 0x7f84ee1d8d60>,
#   <matplotlib.patches.Wedge at 0x7f84ee1e6280>,
#   <matplotlib.patches.Wedge at 0x7f84ee1e6760>,
#   <matplotlib.patches.Wedge at 0x7f84ee1e6c40>,
#   <matplotlib.patches.Wedge at 0x7f84ee1f5160>,
#   <matplotlib.patches.Wedge at 0x7f84ee1f5640>,
#   <matplotlib.patches.Wedge at 0x7f84ee1f5b20>,
#   <matplotlib.patches.Wedge at 0x7f84ee1ff040>,
#   <matplotlib.patches.Wedge at 0x7f84ee1ff520>,
#   <matplotlib.patches.Wedge at 0x7f84ee1ffa00>,
#   <matplotlib.patches.Wedge at 0x7f84ee1ffee0>,
#   <matplotlib.patches.Wedge at 0x7f84ee20e400>,
#   <matplotlib.patches.Wedge at 0x7f84ee20e8e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee20edc0>,
#   <matplotlib.patches.Wedge at 0x7f84ee19a2e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee19a7c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee19aca0>,
#   <matplotlib.patches.Wedge at 0x7f84ee1a81c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee1a86a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee1a8b80>,
#   <matplotlib.patches.Wedge at 0x7f84ee1b60a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee1b6580>,
#   <matplotlib.patches.Wedge at 0x7f84ee1b6a60>,
#   <matplotlib.patches.Wedge at 0x7f84ee1b6f40>,
#   <matplotlib.patches.Wedge at 0x7f84ee1c2460>,
#   <matplotlib.patches.Wedge at 0x7f84ee1c2940>,
#   <matplotlib.patches.Wedge at 0x7f84ee1c2e20>,
#   <matplotlib.patches.Wedge at 0x7f84ee1ce340>,
#   <matplotlib.patches.Wedge at 0x7f84ee1ce820>,
#   <matplotlib.patches.Wedge at 0x7f84ee1ced00>,
#   <matplotlib.patches.Wedge at 0x7f84ee15f220>,
#   <matplotlib.patches.Wedge at 0x7f84ee15f700>,
#   <matplotlib.patches.Wedge at 0x7f84ee15fbe0>,
#   <matplotlib.patches.Wedge at 0x7f84ee16b100>,
#   <matplotlib.patches.Wedge at 0x7f84ee16b5e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee16bac0>,
#   <matplotlib.patches.Wedge at 0x7f84ee16bfa0>,
#   <matplotlib.patches.Wedge at 0x7f84ee1784c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee1789a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee178e80>,
#   <matplotlib.patches.Wedge at 0x7f84ee1853a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee185880>,
#   <matplotlib.patches.Wedge at 0x7f84ee185d60>,
#   <matplotlib.patches.Wedge at 0x7f84ee193280>,
#   <matplotlib.patches.Wedge at 0x7f84ee193760>,
#   <matplotlib.patches.Wedge at 0x7f84ee193c40>,
#   <matplotlib.patches.Wedge at 0x7f84ee120160>,
#   <matplotlib.patches.Wedge at 0x7f84ee120640>,
#   <matplotlib.patches.Wedge at 0x7f84ee120b20>,
#   <matplotlib.patches.Wedge at 0x7f84ee12c040>,
#   <matplotlib.patches.Wedge at 0x7f84ee12c520>,
#   <matplotlib.patches.Wedge at 0x7f84ee12ca00>,
#   <matplotlib.patches.Wedge at 0x7f84ee12cee0>,
#   <matplotlib.patches.Wedge at 0x7f84ee13a400>,
#   <matplotlib.patches.Wedge at 0x7f84ee13a8e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee13adc0>,
#   <matplotlib.patches.Wedge at 0x7f84ee1482e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee1487c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee148ca0>,
#   <matplotlib.patches.Wedge at 0x7f84ee1541c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee1546a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee154b80>,
#   <matplotlib.patches.Wedge at 0x7f84ee0e30a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee0e3580>,
#   <matplotlib.patches.Wedge at 0x7f84ee0e3a60>,
#   <matplotlib.patches.Wedge at 0x7f84ee0e3f40>,
#   <matplotlib.patches.Wedge at 0x7f84ee0ef460>,
#   <matplotlib.patches.Wedge at 0x7f84ee0ef940>,
#   <matplotlib.patches.Wedge at 0x7f84ee0efe20>,
#   <matplotlib.patches.Wedge at 0x7f84ee0fc340>,
#   <matplotlib.patches.Wedge at 0x7f84ee0fc820>,
#   <matplotlib.patches.Wedge at 0x7f84ee0fcd00>,
#   <matplotlib.patches.Wedge at 0x7f84ee10a220>,
#   <matplotlib.patches.Wedge at 0x7f84ee10a700>,
#   <matplotlib.patches.Wedge at 0x7f84ee10abe0>,
#   <matplotlib.patches.Wedge at 0x7f84ee098100>,
#   <matplotlib.patches.Wedge at 0x7f84ee0985e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee098ac0>,
#   <matplotlib.patches.Wedge at 0x7f84ee098fa0>,
#   <matplotlib.patches.Wedge at 0x7f84ee0a44c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee0a49a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee0a4e80>,
#   <matplotlib.patches.Wedge at 0x7f84ee0b13a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee0b1880>,
#   <matplotlib.patches.Wedge at 0x7f84ee0b1d60>,
#   <matplotlib.patches.Wedge at 0x7f84ee0c0280>,
#   <matplotlib.patches.Wedge at 0x7f84ee0c0760>,
#   <matplotlib.patches.Wedge at 0x7f84ee0c0c40>,
#   <matplotlib.patches.Wedge at 0x7f84ee0cd160>,
#   <matplotlib.patches.Wedge at 0x7f84ee0cd640>,
#   <matplotlib.patches.Wedge at 0x7f84ee0cdb20>,
#   <matplotlib.patches.Wedge at 0x7f84ee058040>,
#   <matplotlib.patches.Wedge at 0x7f84ee058520>,
#   <matplotlib.patches.Wedge at 0x7f84ee058a00>,
#   <matplotlib.patches.Wedge at 0x7f84ee058ee0>,
#   <matplotlib.patches.Wedge at 0x7f84ee067400>,
#   <matplotlib.patches.Wedge at 0x7f84ee0678e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee067dc0>,
#   <matplotlib.patches.Wedge at 0x7f84ee0732e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee0737c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee073ca0>,
#   <matplotlib.patches.Wedge at 0x7f84ee0811c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee0816a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee081b80>,
#   <matplotlib.patches.Wedge at 0x7f84ee08f0a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee08f580>,
#   <matplotlib.patches.Wedge at 0x7f84ee08fa60>,
#   <matplotlib.patches.Wedge at 0x7f84ee08ff40>,
#   <matplotlib.patches.Wedge at 0x7f84ee01d460>,
#   <matplotlib.patches.Wedge at 0x7f84ee01d940>,
#   <matplotlib.patches.Wedge at 0x7f84ee01de20>,
#   <matplotlib.patches.Wedge at 0x7f84ee029340>,
#   <matplotlib.patches.Wedge at 0x7f84ee029820>,
#   <matplotlib.patches.Wedge at 0x7f84ee029d00>,
#   <matplotlib.patches.Wedge at 0x7f84ee037220>,
#   <matplotlib.patches.Wedge at 0x7f84ee037700>,
#   <matplotlib.patches.Wedge at 0x7f84ee037be0>,
#   <matplotlib.patches.Wedge at 0x7f84ee043100>,
#   <matplotlib.patches.Wedge at 0x7f84ee0435e0>,
#   <matplotlib.patches.Wedge at 0x7f84ee043ac0>,
#   <matplotlib.patches.Wedge at 0x7f84ee043fa0>,
#   <matplotlib.patches.Wedge at 0x7f84ee0524c0>,
#   <matplotlib.patches.Wedge at 0x7f84ee0529a0>,
#   <matplotlib.patches.Wedge at 0x7f84ee052e80>,
#   <matplotlib.patches.Wedge at 0x7f84edfde3a0>,
#   <matplotlib.patches.Wedge at 0x7f84edfde880>,
#   <matplotlib.patches.Wedge at 0x7f84edfded60>,
#   <matplotlib.patches.Wedge at 0x7f84edfeb280>,
#   <matplotlib.patches.Wedge at 0x7f84edfeb760>,
#   <matplotlib.patches.Wedge at 0x7f84edfebc40>,
#   <matplotlib.patches.Wedge at 0x7f84edffa160>,
#   <matplotlib.patches.Wedge at 0x7f84edffa640>,
#   <matplotlib.patches.Wedge at 0x7f84edffab20>,
#   <matplotlib.patches.Wedge at 0x7f84ee006040>,
#   <matplotlib.patches.Wedge at 0x7f84ee006520>,
#   <matplotlib.patches.Wedge at 0x7f84ee006a00>,
#   <matplotlib.patches.Wedge at 0x7f84ee006ee0>,
#   <matplotlib.patches.Wedge at 0x7f84edf95400>,
#   <matplotlib.patches.Wedge at 0x7f84edf958e0>,
#   <matplotlib.patches.Wedge at 0x7f84edf95dc0>,
#   <matplotlib.patches.Wedge at 0x7f84edf9f2e0>,
#   <matplotlib.patches.Wedge at 0x7f84edf9f7c0>,
#   <matplotlib.patches.Wedge at 0x7f84edf9fca0>,
#   <matplotlib.patches.Wedge at 0x7f84edfad1c0>,
#   <matplotlib.patches.Wedge at 0x7f84edfad6a0>,
#   <matplotlib.patches.Wedge at 0x7f84edfadb80>,
#   <matplotlib.patches.Wedge at 0x7f84edfbd0a0>,
#   <matplotlib.patches.Wedge at 0x7f84edfbd580>,
#   <matplotlib.patches.Wedge at 0x7f84edfbda60>,
#   <matplotlib.patches.Wedge at 0x7f84edfbdf40>,
#   <matplotlib.patches.Wedge at 0x7f84edfc9460>,
#   <matplotlib.patches.Wedge at 0x7f84edfc9940>,
#   <matplotlib.patches.Wedge at 0x7f84edfc9e20>,
#   <matplotlib.patches.Wedge at 0x7f84edfd4340>,
#   <matplotlib.patches.Wedge at 0x7f84edfd4820>,
#   <matplotlib.patches.Wedge at 0x7f84edfd4d00>,
#   <matplotlib.patches.Wedge at 0x7f84edf64220>,
#   <matplotlib.patches.Wedge at 0x7f84edf64700>,
#   <matplotlib.patches.Wedge at 0x7f84edf64be0>,
#   <matplotlib.patches.Wedge at 0x7f84edf71100>,
#   <matplotlib.patches.Wedge at 0x7f84edf715e0>,
#   <matplotlib.patches.Wedge at 0x7f84edf71ac0>,
#   <matplotlib.patches.Wedge at 0x7f84edf71fa0>,
#   <matplotlib.patches.Wedge at 0x7f84edf7d4c0>,
#   <matplotlib.patches.Wedge at 0x7f84edf7d9a0>,
#   <matplotlib.patches.Wedge at 0x7f84edf7de80>,
#   <matplotlib.patches.Wedge at 0x7f84edf8b3a0>,
#   <matplotlib.patches.Wedge at 0x7f84edf8b880>,
#   <matplotlib.patches.Wedge at 0x7f84edf8bd60>,
#   <matplotlib.patches.Wedge at 0x7f84edf18280>,
#   <matplotlib.patches.Wedge at 0x7f84edf18760>,
#   <matplotlib.patches.Wedge at 0x7f84edf18c40>,
#   <matplotlib.patches.Wedge at 0x7f84edf25160>,
#   <matplotlib.patches.Wedge at 0x7f84edf25640>,
#   <matplotlib.patches.Wedge at 0x7f84edf25b20>,
#   <matplotlib.patches.Wedge at 0x7f84edf32040>,
#   <matplotlib.patches.Wedge at 0x7f84edf32520>,
#   <matplotlib.patches.Wedge at 0x7f84edf32a00>,
#   <matplotlib.patches.Wedge at 0x7f84edf32ee0>,
#   <matplotlib.patches.Wedge at 0x7f84edf41400>,
#   <matplotlib.patches.Wedge at 0x7f84edf418e0>,
#   <matplotlib.patches.Wedge at 0x7f84edf41dc0>,
#   <matplotlib.patches.Wedge at 0x7f84edf4c2e0>,
#   <matplotlib.patches.Wedge at 0x7f84edf4c7c0>,
#   <matplotlib.patches.Wedge at 0x7f84edf4cca0>,
#   <matplotlib.patches.Wedge at 0x7f84ededa1c0>,
#   <matplotlib.patches.Wedge at 0x7f84ededa6a0>,
#   <matplotlib.patches.Wedge at 0x7f84ededab80>,
#   <matplotlib.patches.Wedge at 0x7f84edee90a0>,
#   <matplotlib.patches.Wedge at 0x7f84edee9580>,
#   <matplotlib.patches.Wedge at 0x7f84edee9a60>,
#   <matplotlib.patches.Wedge at 0x7f84edee9f40>,
#   <matplotlib.patches.Wedge at 0x7f84edef6460>,
#   <matplotlib.patches.Wedge at 0x7f84edef6940>,
#   <matplotlib.patches.Wedge at 0x7f84edef6e20>,
#   <matplotlib.patches.Wedge at 0x7f84edf01340>,
#   <matplotlib.patches.Wedge at 0x7f84edf01820>,
#   <matplotlib.patches.Wedge at 0x7f84edf01d00>,
#   <matplotlib.patches.Wedge at 0x7f84edf10220>,
#   <matplotlib.patches.Wedge at 0x7f84edf10700>,
#   <matplotlib.patches.Wedge at 0x7f84edf10be0>,
#   <matplotlib.patches.Wedge at 0x7f84ede9e100>,
#   <matplotlib.patches.Wedge at 0x7f84ede9e5e0>,
#   <matplotlib.patches.Wedge at 0x7f84ede9eac0>,
#   <matplotlib.patches.Wedge at 0x7f84ede9efa0>,
#   <matplotlib.patches.Wedge at 0x7f84edeaa4c0>,
#   <matplotlib.patches.Wedge at 0x7f84edeaa9a0>,
#   <matplotlib.patches.Wedge at 0x7f84edeaae80>,
#   <matplotlib.patches.Wedge at 0x7f84edeb73a0>,
#   <matplotlib.patches.Wedge at 0x7f84edeb7880>,
#   <matplotlib.patches.Wedge at 0x7f84edeb7d60>,
#   <matplotlib.patches.Wedge at 0x7f84edec7280>,
#   <matplotlib.patches.Wedge at 0x7f84edec7760>,
#   <matplotlib.patches.Wedge at 0x7f84edec7c40>,
#   <matplotlib.patches.Wedge at 0x7f84eded2160>,
#   <matplotlib.patches.Wedge at 0x7f84eded2640>,
#   <matplotlib.patches.Wedge at 0x7f84eded2b20>,
#   <matplotlib.patches.Wedge at 0x7f84ede5e040>,
#   <matplotlib.patches.Wedge at 0x7f84ede5e520>,
#   <matplotlib.patches.Wedge at 0x7f84ede5ea00>,
#   <matplotlib.patches.Wedge at 0x7f84ede5eee0>,
#   <matplotlib.patches.Wedge at 0x7f84ede6d400>,
#   <matplotlib.patches.Wedge at 0x7f84ede6d8e0>,
#   <matplotlib.patches.Wedge at 0x7f84ede6ddc0>,
#   <matplotlib.patches.Wedge at 0x7f84ede792e0>,
#   <matplotlib.patches.Wedge at 0x7f84ede797c0>,
#   <matplotlib.patches.Wedge at 0x7f84ede79ca0>,
#   <matplotlib.patches.Wedge at 0x7f84ede871c0>,
#   <matplotlib.patches.Wedge at 0x7f84ede876a0>,
#   <matplotlib.patches.Wedge at 0x7f84ede87b80>,
#   <matplotlib.patches.Wedge at 0x7f84ede150a0>,
#   <matplotlib.patches.Wedge at 0x7f84ede15580>,
#   <matplotlib.patches.Wedge at 0x7f84ede15a60>,
#   <matplotlib.patches.Wedge at 0x7f84ede15f40>,
#   <matplotlib.patches.Wedge at 0x7f84ede21460>,
#   <matplotlib.patches.Wedge at 0x7f84ede21940>,
#   <matplotlib.patches.Wedge at 0x7f84ede21e20>,
#   <matplotlib.patches.Wedge at 0x7f84ede30340>,
#   <matplotlib.patches.Wedge at 0x7f84ede30820>,
#   <matplotlib.patches.Wedge at 0x7f84ede30d00>,
#   <matplotlib.patches.Wedge at 0x7f84ede3d220>,
#   <matplotlib.patches.Wedge at 0x7f84ede3d700>,
#   <matplotlib.patches.Wedge at 0x7f84ede3dbe0>,
#   <matplotlib.patches.Wedge at 0x7f84ede48100>,
#   <matplotlib.patches.Wedge at 0x7f84ede485e0>,
#   <matplotlib.patches.Wedge at 0x7f84ede48ac0>,
#   <matplotlib.patches.Wedge at 0x7f84ede48fa0>,
#   <matplotlib.patches.Wedge at 0x7f84eddd74c0>,
#   <matplotlib.patches.Wedge at 0x7f84eddd79a0>,
#   <matplotlib.patches.Wedge at 0x7f84eddd7e80>,
#   <matplotlib.patches.Wedge at 0x7f84edde53a0>,
#   <matplotlib.patches.Wedge at 0x7f84edde5880>,
#   <matplotlib.patches.Wedge at 0x7f84edde5d60>,
#   <matplotlib.patches.Wedge at 0x7f84eddf1280>,
#   <matplotlib.patches.Wedge at 0x7f84eddf1760>,
#   <matplotlib.patches.Wedge at 0x7f84eddf1c40>,
#   <matplotlib.patches.Wedge at 0x7f84eddff160>,
#   <matplotlib.patches.Wedge at 0x7f84eddff640>,
#   <matplotlib.patches.Wedge at 0x7f84eddffb20>,
#   <matplotlib.patches.Wedge at 0x7f84ede0b040>,
#   <matplotlib.patches.Wedge at 0x7f84ede0b520>,
#   <matplotlib.patches.Wedge at 0x7f84ede0ba00>,
#   <matplotlib.patches.Wedge at 0x7f84ede0bee0>,
#   <matplotlib.patches.Wedge at 0x7f84edd9b400>,
#   <matplotlib.patches.Wedge at 0x7f84edd9b8e0>,
#   <matplotlib.patches.Wedge at 0x7f84edd9bdc0>,
#   <matplotlib.patches.Wedge at 0x7f84edda62e0>,
#   <matplotlib.patches.Wedge at 0x7f84edda67c0>,
#   <matplotlib.patches.Wedge at 0x7f84edda6ca0>,
#   <matplotlib.patches.Wedge at 0x7f84eddb41c0>,
#   <matplotlib.patches.Wedge at 0x7f84eddb46a0>,
#   <matplotlib.patches.Wedge at 0x7f84eddb4b80>,
#   <matplotlib.patches.Wedge at 0x7f84eddc20a0>,
#   <matplotlib.patches.Wedge at 0x7f84eddc2580>,
#   <matplotlib.patches.Wedge at 0x7f84eddc2a60>,
#   <matplotlib.patches.Wedge at 0x7f84eddc2f40>,
#   <matplotlib.patches.Wedge at 0x7f84eddce460>,
#   <matplotlib.patches.Wedge at 0x7f84eddce940>,
#   <matplotlib.patches.Wedge at 0x7f84eddcee20>,
#   <matplotlib.patches.Wedge at 0x7f84edd5b340>,
#   <matplotlib.patches.Wedge at 0x7f84edd5b820>,
#   <matplotlib.patches.Wedge at 0x7f84edd5bd00>,
#   <matplotlib.patches.Wedge at 0x7f84edd6b220>,
#   <matplotlib.patches.Wedge at 0x7f84edd6b700>,
#   <matplotlib.patches.Wedge at 0x7f84edd6bbe0>,
#   <matplotlib.patches.Wedge at 0x7f84edd75100>,
#   <matplotlib.patches.Wedge at 0x7f84edd755e0>,
#   <matplotlib.patches.Wedge at 0x7f84edd75ac0>,
#   <matplotlib.patches.Wedge at 0x7f84edd75fa0>,
#   <matplotlib.patches.Wedge at 0x7f84edd834c0>,
#   <matplotlib.patches.Wedge at 0x7f84edd839a0>,
#   <matplotlib.patches.Wedge at 0x7f84edd83e80>,
#   <matplotlib.patches.Wedge at 0x7f84edd923a0>,
#   <matplotlib.patches.Wedge at 0x7f84edd92880>,
#   <matplotlib.patches.Wedge at 0x7f84edd92d60>,
#   <matplotlib.patches.Wedge at 0x7f84edd1e280>,
#   <matplotlib.patches.Wedge at 0x7f84edd1e760>,
#   <matplotlib.patches.Wedge at 0x7f84edd1ec40>,
#   <matplotlib.patches.Wedge at 0x7f84edd2a160>,
#   <matplotlib.patches.Wedge at 0x7f84edd2a640>,
#   <matplotlib.patches.Wedge at 0x7f84edd2ab20>,
#   <matplotlib.patches.Wedge at 0x7f84edd38040>,
#   <matplotlib.patches.Wedge at 0x7f84edd38520>,
#   <matplotlib.patches.Wedge at 0x7f84edd38a00>,
#   <matplotlib.patches.Wedge at 0x7f84edd38ee0>,
#   <matplotlib.patches.Wedge at 0x7f84edd46400>,
#   <matplotlib.patches.Wedge at 0x7f84edd468e0>,
#   <matplotlib.patches.Wedge at 0x7f84edd46dc0>,
#   <matplotlib.patches.Wedge at 0x7f84edd532e0>,
#   <matplotlib.patches.Wedge at 0x7f84edd537c0>,
#   <matplotlib.patches.Wedge at 0x7f84edd53ca0>,
#   <matplotlib.patches.Wedge at 0x7f84edce01c0>,
#   <matplotlib.patches.Wedge at 0x7f84edce06a0>,
#   <matplotlib.patches.Wedge at 0x7f84edce0b80>,
#   <matplotlib.patches.Wedge at 0x7f84edcef0a0>,
#   <matplotlib.patches.Wedge at 0x7f84edcef580>,
#   <matplotlib.patches.Wedge at 0x7f84edcefa60>,
#   <matplotlib.patches.Wedge at 0x7f84edceff40>,
#   <matplotlib.patches.Wedge at 0x7f84edcfb460>,
#   <matplotlib.patches.Wedge at 0x7f84edcfb940>,
# ...
#   Text(-1.0907002238705936, -0.14273409420540434, ''),
#   Text(-1.0907002238705936, -0.14273409420540434, ''),
#   Text(-1.0900251160679684, -0.14780137462490636, ''),
#   Text(-1.0893264663340365, -0.15286546288878078, ''),
#   Text(-1.0893264663340365, -0.15286546288878078, ''),
#   Text(-1.0886042897579584, -0.15792624962485283, ''),
#   Text(-1.0878586019370178, -0.16298362553225135, ''),
#   Text(-1.0878586019370178, -0.16298362553225135, ''),
#   Text(-1.0870894189762859, -0.16803748138377236, ''),
#   Text(-1.0862967574882714, -0.17308770802823667, ''),
#   Text(-1.0854806345925638, -0.1781341963928459, ''),
#   Text(-1.084641067915463, -0.1831768374855408, ''),
#   Text(-1.0837780755895974, -0.18821552239735423, ''),
#   Text(-1.0828916762535346, -0.1932501423047614, ''),
#   Text(-1.0828916762535346, -0.1932501423047614, ''),
#   Text(-1.0828916762535346, -0.1932501423047614, ''),
#   Text(-1.081981889051376, -0.19828058847203353, ''),
#   Text(-1.0800922301503673, -0.20832852509631597, ''),
#   Text(-1.0781092621341117, -0.21835846422944413, ''),
#   Text(-1.0770828404271942, -0.22336641389718312, ''),
#   Text(-1.0770828404271942, -0.22336641389718312, ''),
#   Text(-1.0760331563111198, -0.22836953938546495, ''),
#   Text(-1.074960232456551, -0.23336773263876467, ''),
#   Text(-1.074960232456551, -0.23336773263876467, ''),
#   Text(-1.074960232456551, -0.23336773263876467, ''),
#   Text(-1.0738640920360727, -0.23836088570808198, ''),
#   Text(-1.0716022566943277, -0.2483316400453717, ''),
#   Text(-1.0704366106232863, -0.2533090259689363, ''),
#   Text(-1.0704366106232863, -0.2533090259689363, ''),
#   Text(-1.0704366106232863, -0.2533090259689363, ''),
